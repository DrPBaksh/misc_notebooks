# %% [markdown]
# # Cleaning dates in pandas

# %% [markdown]
# Often we encounter dates in different formats. Pandas has a helpful method called pd.to_datetime which can be good for converting dates in their string format to a datetime format. It is good to get dates in their date time format since it makes them far easier to work with.
#
# https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html
#
# A further resource on pd.to_datetime can be found here
#
# https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html

# %% [markdown]
# Lets look at a few examples of using pd.to_datetime since it could be what you need early on and do not need very customised functions. THe codes below will help us
#
# - %Y: Four-digit year
# - %y: Two-digit year
# - %m: Two-digit month [01, 12]
# - %d: Two-digit day [01, 31]
# - %H: Hour (24-hour clock) [00, 23]
# - %I: Hour (12-hour clock) [01, 12]
# - %M: Two-digit minute [00, 59]
# - %S: Second [00, 61]
# - %f: Microsecond [000000, 999999]
#
# This link gives us even more
# https://dataindependent.com/pandas/pandas-to-datetime-string-to-date-pd-to_datetime/

# %%
import pandas as pd
date_1 = "01-03-18"
pd.to_datetime(date_1, format = "%d-%m-%y")
# Out:
# Timestamp('2018-03-01 00:00:00')

# %% [markdown]
# Notice if i put the format in wrong it throws an error

# %%
pd.to_datetime(date_1, format = "%d-%m-%Y") # this will error

# %% [markdown]
# Example 2

# %%
date_2 = "15/Jan/2020"
pd.to_datetime(date_2, format = "%d/%b/%Y")
# Out:
# Timestamp('2020-01-15 00:00:00')

# %% [markdown]
# Example 3

# %%
date_3 = "1/March/2020"
pd.to_datetime(date_3, format = "%d/%B/%Y")
# Out:
# Timestamp('2020-03-01 00:00:00')

# %% [markdown]
# Example 4

# %%
date_3 = "3rd april 1954"
pd.to_datetime(date_3, format = "%drd %B %Y")
# Out:
# Timestamp('1954-04-03 00:00:00')

# %% [markdown]
# ### Real date data
#
# Often the problem with real data is that date format comes in in a variety of formats and often in a complete mess. Below we are going to walk through a process (and by no doubt the most efficient) that I have gone through to clean some date time data. In the analysis below using pd.datetime could have simplified things in heinds sight - so bare that in mind

# %%
import pandas as pd

# %% [markdown]
# Only Dates is a spreadhseet that has had all the other data removed and just the date columns. We are going to use this spreadsheet to explore the data in the date columns

# %%
xl= pd.read_excel('OnlyDates.xlsx', sheet_name = None)

sheet_names = xl.keys() 
sheet_names
# Out:
# dict_keys(['2021', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012'])

# %%
column_of_dates = []
years = []
for name in sheet_names:
    df = pd.read_excel('OnlyDates.xlsx', sheet_name = name)
    for i in range(len(df)):
        column_of_dates.append(df.values[i][0])
        years.append(int(name))

# %% [markdown]
# I now have two lists. One that contains a list of all the dates across the various sheets. The other is making use of the sheet name so I have a list of years that I have got from the sheet name. I will then make a dataframe from this

# %%
df = pd.DataFrame({'raw_date' : column_of_dates, 'year': years})
df.head()
# Out:
#         raw_date  year
# 0  12th Jan 2021  2021
# 1  13th Jan 2021  2021
# 2  13th Jan 2021  2021
# 3  16th Jan 2021  2021
# 4  23rd Jan 2021  2021

# %% [markdown]
# In order to get an idea of the tpyes of date formats I have I have used the sample method

# %%
df.sample(100)
# Out:
#                  raw_date  year
# 1154              27/6/13  2013
# 463   2017-02-15 00:00:00  2017
# 1335  2012-09-03 00:00:00  2012
# 414             07.Oct.18  2018
# 1320  2012-07-11 00:00:00  2012
# ...                   ...   ...
# 106         17th Oct 2021  2021
# 857   2015-05-15 00:00:00  2015
# 776   2110-10-20 00:00:00  2016
# 893   2015-08-26 00:00:00  2015
# 1043             14/11/14  2014
#
# [100 rows x 2 columns]

# %% [markdown]
# Immediately I can see this is dirty. We have some records that look like they are already in dat time format and others that are in various other formats of strings. Run the cell above a few times to get a feel

# %% [markdown]
# From looking at the data above I am going to have to have different approaches for the different formats the date is commin in at. I am going to make this slightly easier to visualise by dividing the data up by the number of numerical digits in the date column.
#
# I have made a custom function that will count the number of digits in the date record. If it cant count it for some reason it will return None when applied to the dataframe using the apply method. I have also created a function that looks if the data is already in a date time format

# %%
from  datetime import datetime
def count_digits(string):
    try:
        return sum(x.isdigit() for x in string)
    except:
        return None
        
def check_datetime(string):
    if isinstance(string, datetime):
        return 1
    else:
        return 0

# %% [markdown]
# In order to apply these functions to the dataframe I am going to use the pandas apply method in combination with a lambda function
#
# ##### lambda function
#
# A Python lambda function is a small anonymous function that can take any number of arguments, but can only have one expression. The syntax for a lambda function is:
#
#
# lambda arguments : expression
#
# The expression is executed and returned when the function is called. The lambda function is often used as an argument to higher-order functions such as map(), filter(), or reduce(). Here's an example:

# %%
lam_function = lambda x : x*6
lam_function(5)
# Out:
# 30

# %% [markdown]
# We are going to use the Python pandas apply method
#
# #### Pandas apply method
#
# The apply() method in Pandas is used to apply a function to each element or row/column of a DataFrame. The function can be either a built-in or user-defined.
#
# The basic syntax for using apply() is:
#
# df.apply(function, axis=0)
#
# df is the Pandas DataFrame on which the method is applied.
#
# function is the function to be applied. It can be a built-in function or a user-defined function.
#
# axis is an optional parameter that specifies along which axis the function should be applied.axis=0 means apply the function along the rows (i.e., to each element in a row), and axis=1 means apply the function along the columns (i.e., to each element in a column).
#
#
# #### Pandas apply with lambda
#
#
# Lambda and apply functions in Python can be used together to create anonymous functions, which can then be passed as arguments to higher-order functions like apply.
#
# For example, let's say you have a Pandas DataFrame and you want to apply a custom function to a particular column. You can use the lambda function to create an anonymous function, and then pass it as an argument to the apply method on the column:

# %% [markdown]
# Below we shall use lambda and apply to apply the count digits and chec_datetime to our data

# %%
df['raw_datetime_format'] = df.raw_date.apply(lambda x : check_datetime(x))
df['digit_number'] = df.raw_date.apply(lambda x : count_digits(x))
df.head()
# Out:
#         raw_date  year  raw_datetime_format  digit_number
# 0  12th Jan 2021  2021                    0           6.0
# 1  13th Jan 2021  2021                    0           6.0
# 2  13th Jan 2021  2021                    0           6.0
# 3  16th Jan 2021  2021                    0           6.0
# 4  23rd Jan 2021  2021                    0           6.0

# %% [markdown]
# Now I am going to view sections of the data depending on the numeric characters on how to clean it

# %%
df[df.raw_datetime_format ==0]
# Out:
#            raw_date  year  raw_datetime_format  digit_number
# 0     12th Jan 2021  2021                    0           6.0
# 1     13th Jan 2021  2021                    0           6.0
# 2     13th Jan 2021  2021                    0           6.0
# 3     16th Jan 2021  2021                    0           6.0
# 4     23rd Jan 2021  2021                    0           6.0
# ...             ...   ...                  ...           ...
# 1215            (D)  2012                    0           0.0
# 1316            NaN  2012                    0           NaN
# 1330         8/1812  2012                    0           5.0
# 1365      11/291/12  2012                    0           7.0
# 1379            NaN  2012                    0           NaN
#
# [470 rows x 4 columns]

# %% [markdown]
# Above we see records that have not been recognised as datetime
#
# Now we shall filter by number of digits

# %%
df[df.digit_number ==0]
# Out:
#                                         raw_date  year  raw_datetime_format  \
# 291                                 day/month/yr  2018                    0
# 443                                 day/month/yr  2017                    0
# 588                                 day/month/yr  2016                    0
# 810                                 day/month/yr  2015                    0
# 945           Date of injury or onset of illness  2014                    0
# 947                                 day/month/yr  2014                    0
# 948                                          (D)  2014                    0
# 1064  Log of Work-Related Injuries and Illnesses  2013                    0
# 1065          Date of injury or onset of illness  2013                    0
# 1067                                 (month/day)  2013                    0
# 1068                                         (D)  2013                    0
# 1211  Log of Work-Related Injuries and Illnesses  2012                    0
# 1212          Date of injury or onset of illness  2012                    0
# 1214                                 (month/day)  2012                    0
# 1215                                         (D)  2012                    0
#
#       digit_number
# 291            0.0
# 443            0.0
# 588            0.0
# 810            0.0
# 945            0.0
# 947            0.0
# 948            0.0
# 1064           0.0
# 1065           0.0
# 1067           0.0
# 1068           0.0
# 1211           0.0
# 1212           0.0
# 1214           0.0
# 1215           0.0

# %% [markdown]
# Looking at the above if there is not number in there then we can say this is not a date. We will create an extra columns that flag these records as non dates

# %%
df['cleaned_date'] = ['NOT A DATE' if df.digit_number.iloc[i] ==0 else 'DATE' for i in range(len(df))]
df.sample(10)
# Out:
#                  raw_date  year  raw_datetime_format  digit_number  \
# 1243  2012-02-24 00:00:00  2012                    1           NaN
# 1337  2012-09-10 00:00:00  2012                    1           NaN
# 692   2016-07-02 00:00:00  2016                    1           NaN
# 845   2015-04-20 00:00:00  2015                    1           NaN
# 1099              15/3/13  2013                    0           5.0
# 629   2016-02-25 00:00:00  2016                    1           NaN
# 1328  2012-08-09 00:00:00  2012                    1           NaN
# 1304  2012-06-14 00:00:00  2012                    1           NaN
# 580   2017-11-15 00:00:00  2017                    1           NaN
# 567   2017-09-10 00:00:00  2017                    1           NaN
#
#      cleaned_date
# 1243         DATE
# 1337         DATE
# 692          DATE
# 845          DATE
# 1099         DATE
# 629          DATE
# 1328         DATE
# 1304         DATE
# 580          DATE
# 567          DATE

# %% [markdown]
# Lets look at number of digits 1 and 2 together

# %%
df[df.digit_number ==1]
# Out:
#        raw_date  year  raw_datetime_format  digit_number cleaned_date
# 293     4th Jan  2018                    0           1.0         DATE
# 294     4th Jan  2018                    0           1.0         DATE
# 312   7th March  2018                    0           1.0         DATE
# 346     6th May  2018                    0           1.0         DATE
# 363    3rd June  2018                    0           1.0         DATE
# 381    9th July  2018                    0           1.0         DATE
# 390  7th August  2018                    0           1.0         DATE
# 405    9th Sept  2018                    0           1.0         DATE

# %%
df[df.digit_number ==2]
# Out:
#             raw_date  year  raw_datetime_format  digit_number cleaned_date
# 182       30th March  2019                    0           2.0         DATE
# 183       31st March  2019                    0           2.0         DATE
# 290   04th December   2019                    0           2.0         DATE
# 300         27th Jan  2018                    0           2.0         DATE
# 302         31st Jan  2018                    0           2.0         DATE
# 303         31st jan  2018                    0           2.0         DATE
# 328       24th March  2018                    0           2.0         DATE
# 329       25th March  2018                    0           2.0         DATE
# 331       30th March  2018                    0           2.0         DATE
# 332       31st March  2018                    0           2.0         DATE
# 340       15th April  2018                    0           2.0         DATE
# 342       16th April  2018                    0           2.0         DATE
# 348         10yh May  2018                    0           2.0         DATE
# 350         14th May  2018                    0           2.0         DATE
# 353         17th May  2018                    0           2.0         DATE
# 355         18th May  2018                    0           2.0         DATE
# 360         24th-May  2018                    0           2.0         DATE
# 368        11th June  2018                    0           2.0         DATE
# 372        18th June  2018                    0           2.0         DATE
# 377        28th June  2018                    0           2.0         DATE
# 406        15th Sept  2018                    0           2.0         DATE
# 409   25th November   2018                    0           2.0         DATE
# 421  01st  November   2018                    0           2.0         DATE
# 422   07th November   2018                    0           2.0         DATE
# 423   07th November   2018                    0           2.0         DATE
# 424   10th November   2018                    0           2.0         DATE
# 425   12th November   2018                    0           2.0         DATE
# 426   15th November   2018                    0           2.0         DATE
# 427   19th November   2018                    0           2.0         DATE
# 428   21st November   2018                    0           2.0         DATE
# 429   21st November   2018                    0           2.0         DATE
# 430   22nd November   2018                    0           2.0         DATE
# 431   23rd November   2018                    0           2.0         DATE
# 432    24th November  2018                    0           2.0         DATE
# 433   25th November   2018                    0           2.0         DATE
# 434    26th November  2018                    0           2.0         DATE
# 435    28th November  2018                    0           2.0         DATE
# 436   03rd December   2018                    0           2.0         DATE
# 437   03rd December   2018                    0           2.0         DATE
# 438   04th December   2018                    0           2.0         DATE
# 439  08th  December   2018                    0           2.0         DATE
# 440   12th December   2018                    0           2.0         DATE
# 441   17th December   2018                    0           2.0         DATE
# 442   28th December   2018                    0           2.0         DATE

# %% [markdown]
# It seems for this type of format the user has not put in the year. But we can get that from the sheet name. Our task is to extract the number and the month. We will write a function below to do this.
#
# First we extract the month by looking for string pattersn in the 3 letter month.

# %%
months = ["jan", "feb", "mar", "apr", "may", "jun", "jul", "aug", "sep", "oct", "nov", "dec"]
def extract_month(x, string_list):
    
    input_string = str(x.raw_date).lower()
    date_t = x.raw_datetime_format
    if date_t ==0:
        for substring in string_list:
            if substring in input_string:
                return  str(string_list.index(substring) + 1).zfill(2)
        return None
    else:
        return None

df['month'] = df.apply(lambda x : extract_month(x, months), axis = 1)

# %% [markdown]
# We will then look to extract the digits before the month. The day seem to have standard th rd after them. So we shall use regular expressionsn to pull out these days. Depending on if its 01 or 1 we deal with it slightly differently

# %%
df[df.digit_number ==2].sample(10)
# Out:
#            raw_date  year  raw_datetime_format  digit_number cleaned_date  \
# 340      15th April  2018                    0           2.0         DATE
# 424  10th November   2018                    0           2.0         DATE
# 350        14th May  2018                    0           2.0         DATE
# 438  04th December   2018                    0           2.0         DATE
# 423  07th November   2018                    0           2.0         DATE
# 332      31st March  2018                    0           2.0         DATE
# 434   26th November  2018                    0           2.0         DATE
# 440  12th December   2018                    0           2.0         DATE
# 302        31st Jan  2018                    0           2.0         DATE
# 427  19th November   2018                    0           2.0         DATE
#
#     month
# 340    04
# 424    11
# 350    05
# 438    12
# 423    11
# 332    03
# 434    11
# 440    12
# 302    01
# 427    11

# %%
import re

def extract_day_2_digits(x):
    input_string = str(x.raw_date)
    date_t = x.raw_datetime_format
    if date_t ==0:
        pattern = r'\b\d{1,2}(?:rd|th|st|nd|yh)\b'
        match = re.search(pattern, input_string)
        if match:
            if len(str(match.group()))==4:
                return str(match.group())[0:2]
            else:
                return str(match.group())[0:1].zfill(2)
        return None
    else:
        return None

df['day'] = df.apply(lambda x : extract_day_2_digits(x), axis = 1)

# %% [markdown]
# Below we can see how the month and the day have been succesfuly retrieved

# %%
df[(df.digit_number ==2) |(df.digit_number ==1) ]
# Out:
#             raw_date  year  raw_datetime_format  digit_number cleaned_date  \
# 182       30th March  2019                    0           2.0         DATE
# 183       31st March  2019                    0           2.0         DATE
# 290   04th December   2019                    0           2.0         DATE
# 293          4th Jan  2018                    0           1.0         DATE
# 294          4th Jan  2018                    0           1.0         DATE
# 300         27th Jan  2018                    0           2.0         DATE
# 302         31st Jan  2018                    0           2.0         DATE
# 303         31st jan  2018                    0           2.0         DATE
# 312        7th March  2018                    0           1.0         DATE
# 328       24th March  2018                    0           2.0         DATE
# 329       25th March  2018                    0           2.0         DATE
# 331       30th March  2018                    0           2.0         DATE
# 332       31st March  2018                    0           2.0         DATE
# 340       15th April  2018                    0           2.0         DATE
# 342       16th April  2018                    0           2.0         DATE
# 346          6th May  2018                    0           1.0         DATE
# 348         10yh May  2018                    0           2.0         DATE
# 350         14th May  2018                    0           2.0         DATE
# 353         17th May  2018                    0           2.0         DATE
# 355         18th May  2018                    0           2.0         DATE
# 360         24th-May  2018                    0           2.0         DATE
# 363         3rd June  2018                    0           1.0         DATE
# 368        11th June  2018                    0           2.0         DATE
# 372        18th June  2018                    0           2.0         DATE
# 377        28th June  2018                    0           2.0         DATE
# 381         9th July  2018                    0           1.0         DATE
# 390       7th August  2018                    0           1.0         DATE
# 405         9th Sept  2018                    0           1.0         DATE
# 406        15th Sept  2018                    0           2.0         DATE
# 409   25th November   2018                    0           2.0         DATE
# 421  01st  November   2018                    0           2.0         DATE
# 422   07th November   2018                    0           2.0         DATE
# 423   07th November   2018                    0           2.0         DATE
# 424   10th November   2018                    0           2.0         DATE
# 425   12th November   2018                    0           2.0         DATE
# 426   15th November   2018                    0           2.0         DATE
# 427   19th November   2018                    0           2.0         DATE
# 428   21st November   2018                    0           2.0         DATE
# 429   21st November   2018                    0           2.0         DATE
# 430   22nd November   2018                    0           2.0         DATE
# 431   23rd November   2018                    0           2.0         DATE
# 432    24th November  2018                    0           2.0         DATE
# 433   25th November   2018                    0           2.0         DATE
# 434    26th November  2018                    0           2.0         DATE
# 435    28th November  2018                    0           2.0         DATE
# 436   03rd December   2018                    0           2.0         DATE
# 437   03rd December   2018                    0           2.0         DATE
# 438   04th December   2018                    0           2.0         DATE
# 439  08th  December   2018                    0           2.0         DATE
# 440   12th December   2018                    0           2.0         DATE
# 441   17th December   2018                    0           2.0         DATE
# 442   28th December   2018                    0           2.0         DATE
#
#     month day
# 182    03  30
# 183    03  31
# 290    12  04
# 293    01  04
# 294    01  04
# 300    01  27
# 302    01  31
# 303    01  31
# 312    03  07
# 328    03  24
# 329    03  25
# 331    03  30
# 332    03  31
# 340    04  15
# 342    04  16
# 346    05  06
# 348    05  10
# 350    05  14
# 353    05  17
# 355    05  18
# 360    05  24
# 363    06  03
# 368    06  11
# 372    06  18
# 377    06  28
# 381    07  09
# 390    08  07
# 405    09  09
# 406    09  15
# 409    11  25
# 421    11  01
# 422    11  07
# 423    11  07
# 424    11  10
# 425    11  12
# 426    11  15
# 427    11  19
# 428    11  21
# 429    11  21
# 430    11  22
# 431    11  23
# 432    11  24
# 433    11  25
# 434    11  26
# 435    11  28
# 436    12  03
# 437    12  03
# 438    12  04
# 439    12  08
# 440    12  12
# 441    12  17
# 442    12  28

# %% [markdown]
# Lets now look at digits 3 and 4

# %%
df[df.digit_number ==3]
# Out:
# Empty DataFrame
# Columns: [raw_date, year, raw_datetime_format, digit_number, cleaned_date, month, day]
# Index: []

# %%
df[df.digit_number ==4]
# Out:
#        raw_date  year  raw_datetime_format  digit_number cleaned_date month  \
# 347   06.May.18  2018                    0           4.0         DATE    05
# 349   13.May.18  2018                    0           4.0         DATE    05
# 351   15.May 18  2018                    0           4.0         DATE    05
# 352   15.May.18  2018                    0           4.0         DATE    05
# 354   17.May.18  2018                    0           4.0         DATE    05
# 356   22.May 18  2018                    0           4.0         DATE    05
# 358   23.May 18  2018                    0           4.0         DATE    05
# 411   04.Oct.18  2018                    0           4.0         DATE    10
# 412   04.Oct.18  2018                    0           4.0         DATE    10
# 413   05.Oct.18  2018                    0           4.0         DATE    10
# 414   07.Oct.18  2018                    0           4.0         DATE    10
# 415   15.Oct.18  2018                    0           4.0         DATE    10
# 416   17.Oct.18  2018                    0           4.0         DATE    10
# 417   17.Oct.18  2018                    0           4.0         DATE    10
# 418   25.Oct.18  2018                    0           4.0         DATE    10
# 419   25.Oct.18  2018                    0           4.0         DATE    10
# 420   31.Oct.18  2018                    0           4.0         DATE    10
# 468     20-Fr17  2017                    0           4.0         DATE  None
# 685  23-Juns-16  2016                    0           4.0         DATE    06
# 766  10-Oct-=16  2016                    0           4.0         DATE    10
# 803     17-De16  2016                    0           4.0         DATE  None
# 809  16-=Dec-16  2016                    0           4.0         DATE    12
# 979     8//5/14  2014                    0           4.0         DATE  None
#
#       day
# 347  None
# 349  None
# 351  None
# 352  None
# 354  None
# 356  None
# 358  None
# 411  None
# 412  None
# 413  None
# 414  None
# 415  None
# 416  None
# 417  None
# 418  None
# 419  None
# 420  None
# 468  None
# 685  None
# 766  None
# 803  None
# 809  None
# 979  None

# %% [markdown]
# We can see in this sample there are dates which are separated by a dot. The previous transformations have detected the month but the day still does not work . So lets write a function to pull out the day before the dot

# %%
def extract_day_before_dot(x):
    input_string = str(x.raw_date)
    date_t = x.raw_datetime_format
    day_correct = str(x.day)
    if len(day_correct) != 2:
        if date_t ==0:
            input_string = input_string.strip()
            day = input_string.split('.')[0:3][0]
            if len(day)<3:
                return day.zfill(2)
            else:
                return None
        else:
            return None
            
    else:
        return day_correct



df['day'] = df.apply(lambda x : extract_day_before_dot(x), axis = 1)

# %% [markdown]
# Alternaitvely you could have used pd.to_datetime(input_string, format = "%d.%b.%y") however i didnt find it working well

# %%
df[df.digit_number ==4]
# Out:
#        raw_date  year  raw_datetime_format  digit_number cleaned_date month  \
# 347   06.May.18  2018                    0           4.0         DATE    05
# 349   13.May.18  2018                    0           4.0         DATE    05
# 351   15.May 18  2018                    0           4.0         DATE    05
# 352   15.May.18  2018                    0           4.0         DATE    05
# 354   17.May.18  2018                    0           4.0         DATE    05
# 356   22.May 18  2018                    0           4.0         DATE    05
# 358   23.May 18  2018                    0           4.0         DATE    05
# 411   04.Oct.18  2018                    0           4.0         DATE    10
# 412   04.Oct.18  2018                    0           4.0         DATE    10
# 413   05.Oct.18  2018                    0           4.0         DATE    10
# 414   07.Oct.18  2018                    0           4.0         DATE    10
# 415   15.Oct.18  2018                    0           4.0         DATE    10
# 416   17.Oct.18  2018                    0           4.0         DATE    10
# 417   17.Oct.18  2018                    0           4.0         DATE    10
# 418   25.Oct.18  2018                    0           4.0         DATE    10
# 419   25.Oct.18  2018                    0           4.0         DATE    10
# 420   31.Oct.18  2018                    0           4.0         DATE    10
# 468     20-Fr17  2017                    0           4.0         DATE  None
# 685  23-Juns-16  2016                    0           4.0         DATE    06
# 766  10-Oct-=16  2016                    0           4.0         DATE    10
# 803     17-De16  2016                    0           4.0         DATE  None
# 809  16-=Dec-16  2016                    0           4.0         DATE    12
# 979     8//5/14  2014                    0           4.0         DATE  None
#
#       day
# 347    06
# 349    13
# 351    15
# 352    15
# 354    17
# 356    22
# 358    23
# 411    04
# 412    04
# 413    05
# 414    07
# 415    15
# 416    17
# 417    17
# 418    25
# 419    25
# 420    31
# 468  None
# 685  None
# 766  None
# 803  None
# 809  None
# 979  None

# %% [markdown]
# We can see we have got some of the dates with that however there are some that are still typos. We will leave them however the format with the two // lets extract that

# %%
df[df.digit_number ==5]
# Out:
#            raw_date  year  raw_datetime_format  digit_number cleaned_date  \
# 10     5th Mar 2021  2021                    0           5.0         DATE
# 79     9th Jul 2021  2021                    0           5.0         DATE
# 102    8th Oct 2021  2021                    0           5.0         DATE
# 103    8th Oct 2021  2021                    0           5.0         DATE
# 362   4th June 2018  2018                    0           5.0         DATE
# ...             ...   ...                  ...           ...          ...
# 1184        18/9/13  2013                    0           5.0         DATE
# 1185        24/9/13  2013                    0           5.0         DATE
# 1186        25/9/13  2013                    0           5.0         DATE
# 1187        26/9/13  2013                    0           5.0         DATE
# 1330         8/1812  2012                    0           5.0         DATE
#
#      month   day
# 10      03    05
# 79      07    09
# 102     10    08
# 103     10    08
# 362     06    04
# ...    ...   ...
# 1184  None  None
# 1185  None  None
# 1186  None  None
# 1187  None  None
# 1330  None  None
#
# [124 rows x 7 columns]

# %%
def double_slash_datetime(x):
    input_string = str(x.raw_date)
    date_t = x.raw_datetime_format
    day_correct = str(x.day)
    if date_t ==0:
        pattern = r'.*(?<!/)/(?!/).*(?<!/)/(?!/).*'
        if re.match(pattern, input_string):
            try:
                date_time_format = pd.to_datetime(input_string)
                x.day = date_time_format.day
                x.month = date_time_format.month
                return x
            except:
                return x
        else:
            return x
    else: 
        return x

# %% [markdown]
# Note we could have made use of pd.to_datetime(input_String, "%d/%m/%y") however as before i dint find it worked well

# %%
df = df.apply(lambda x : double_slash_datetime(x), axis = 1)

# %%
df[df.digit_number ==5]
# Out:
#            raw_date  year  raw_datetime_format  digit_number cleaned_date  \
# 10     5th Mar 2021  2021                    0           5.0         DATE
# 79     9th Jul 2021  2021                    0           5.0         DATE
# 102    8th Oct 2021  2021                    0           5.0         DATE
# 103    8th Oct 2021  2021                    0           5.0         DATE
# 362   4th June 2018  2018                    0           5.0         DATE
# ...             ...   ...                  ...           ...          ...
# 1184        18/9/13  2013                    0           5.0         DATE
# 1185        24/9/13  2013                    0           5.0         DATE
# 1186        25/9/13  2013                    0           5.0         DATE
# 1187        26/9/13  2013                    0           5.0         DATE
# 1330         8/1812  2012                    0           5.0         DATE
#
#      month   day
# 10      03    05
# 79      07    09
# 102     10    08
# 103     10    08
# 362     06    04
# ...    ...   ...
# 1184     9    18
# 1185     9    24
# 1186     9    25
# 1187     9    26
# 1330  None  None
#
# [124 rows x 7 columns]

# %%
df[df.digit_number ==6]
# Out:
#            raw_date  year  raw_datetime_format  digit_number cleaned_date  \
# 0     12th Jan 2021  2021                    0           6.0         DATE
# 1     13th Jan 2021  2021                    0           6.0         DATE
# 2     13th Jan 2021  2021                    0           6.0         DATE
# 3     16th Jan 2021  2021                    0           6.0         DATE
# 4     23rd Jan 2021  2021                    0           6.0         DATE
# ...             ...   ...                  ...           ...          ...
# 1206       22/11/13  2013                    0           6.0         DATE
# 1207       26/11/13  2013                    0           6.0         DATE
# 1208       30/11/13  2013                    0           6.0         DATE
# 1209       15/12/13  2013                    0           6.0         DATE
# 1210       21/12/13  2013                    0           6.0         DATE
#
#      month day
# 0       01  12
# 1       01  13
# 2       01  13
# 3       01  16
# 4       01  23
# ...    ...  ..
# 1206    11  22
# 1207    11  26
# 1208    11  30
# 1209    12  15
# 1210    12  21
#
# [222 rows x 7 columns]

# %% [markdown]
# Now we can combine all our date year and month columns together into a date time format

# %%
def combined_date(x):
    date_t = x.raw_datetime_format
    if date_t == 1:
        return x.raw_date
    else:
        try:
        
            date_string = str(x.month) +'-' + str(x.day) + '-' + str(x.year)
            return pd.to_datetime(date_string)
                                 
        except:
            return None
        
def usa_convert(x):
    try:
        date_obj = x.combined_date
        return  date_obj.strftime('%m/%d/%Y')
    except:
        return None
    
def check_date(x):
    try:
        if len(x.combined_date_USA) == 10:
            return True
        else:
            return False
    except:
        return False

    
df['combined_date'] = df.apply(lambda x : combined_date(x), axis = 1)    
df['combined_date_USA'] = df.apply(lambda x: usa_convert(x), axis =1 )
df['date_format'] = df.apply(lambda x: check_date(x), axis = 1)

# %%
df.head()
# Out:
#         raw_date  year  raw_datetime_format  digit_number cleaned_date month  \
# 0  12th Jan 2021  2021                    0           6.0         DATE    01
# 1  13th Jan 2021  2021                    0           6.0         DATE    01
# 2  13th Jan 2021  2021                    0           6.0         DATE    01
# 3  16th Jan 2021  2021                    0           6.0         DATE    01
# 4  23rd Jan 2021  2021                    0           6.0         DATE    01
#
#   day combined_date combined_date_USA  date_format
# 0  12    2021-01-12        01/12/2021         True
# 1  13    2021-01-13        01/13/2021         True
# 2  13    2021-01-13        01/13/2021         True
# 3  16    2021-01-16        01/16/2021         True
# 4  23    2021-01-23        01/23/2021         True

# %% [markdown]
# We have also labelled the data now that we could not convert. This could be easily flagged and changed manually

# %%
df[df.date_format == False]
# Out:
#                                         raw_date  year  raw_datetime_format  \
# 63                                  19th 05.2021  2021                    0
# 223                               9/1/201+G4:M99  2019                    0
# 271                                          NaN  2019                    0
# 272                                          NaN  2019                    0
# 273                                          NaN  2019                    0
# 274                                          NaN  2019                    0
# 275                                          NaN  2019                    0
# 276                                          NaN  2019                    0
# 277                                          NaN  2019                    0
# 278                                          NaN  2019                    0
# 279                                          NaN  2019                    0
# 280                                          NaN  2019                    0
# 281                                          NaN  2019                    0
# 282                                          NaN  2019                    0
# 283                                          NaN  2019                    0
# 284                                          NaN  2019                    0
# 285                                          NaN  2019                    0
# 286                                          NaN  2019                    0
# 287                                          NaN  2019                    0
# 288                                          NaN  2019                    0
# 289                                          NaN  2019                    0
# 291                                 day/month/yr  2018                    0
# 311                                     28-02-18  2018                    0
# 443                                 day/month/yr  2017                    0
# 468                                      20-Fr17  2017                    0
# 588                                 day/month/yr  2016                    0
# 623                                    18-Feb016  2016                    0
# 685                                   23-Juns-16  2016                    0
# 700                                          NaN  2016                    0
# 766                                   10-Oct-=16  2016                    0
# 803                                      17-De16  2016                    0
# 809                                   16-=Dec-16  2016                    0
# 810                                 day/month/yr  2015                    0
# 909                                   02109/2015  2015                    0
# 925                                        42312  2015                    0
# 926                                        42315  2015                    0
# 944                                          NaN  2014                    0
# 945           Date of injury or onset of illness  2014                    0
# 946                                          NaN  2014                    0
# 947                                 day/month/yr  2014                    0
# 948                                          (D)  2014                    0
# 979                                      8//5/14  2014                    0
# 997                                    6/7//2014  2014                    0
# 1064  Log of Work-Related Injuries and Illnesses  2013                    0
# 1065          Date of injury or onset of illness  2013                    0
# 1066                                         NaN  2013                    0
# 1067                                 (month/day)  2013                    0
# 1068                                         (D)  2013                    0
# 1078                                         NaN  2013                    0
# 1211  Log of Work-Related Injuries and Illnesses  2012                    0
# 1212          Date of injury or onset of illness  2012                    0
# 1213                                         NaN  2012                    0
# 1214                                 (month/day)  2012                    0
# 1215                                         (D)  2012                    0
# 1316                                         NaN  2012                    0
# 1330                                      8/1812  2012                    0
# 1365                                   11/291/12  2012                    0
# 1379                                         NaN  2012                    0
#
#       digit_number cleaned_date month   day combined_date combined_date_USA  \
# 63             8.0         DATE  None    19           NaT              None
# 223            8.0         DATE  None  None           NaT              None
# 271            NaN         DATE  None  None           NaT              None
# 272            NaN         DATE  None  None           NaT              None
# 273            NaN         DATE  None  None           NaT              None
# 274            NaN         DATE  None  None           NaT              None
# 275            NaN         DATE  None  None           NaT              None
# 276            NaN         DATE  None  None           NaT              None
# 277            NaN         DATE  None  None           NaT              None
# 278            NaN         DATE  None  None           NaT              None
# 279            NaN         DATE  None  None           NaT              None
# 280            NaN         DATE  None  None           NaT              None
# 281            NaN         DATE  None  None           NaT              None
# 282            NaN         DATE  None  None           NaT              None
# 283            NaN         DATE  None  None           NaT              None
# 284            NaN         DATE  None  None           NaT              None
# 285            NaN         DATE  None  None           NaT              None
# 286            NaN         DATE  None  None           NaT              None
# 287            NaN         DATE  None  None           NaT              None
# 288            NaN         DATE  None  None           NaT              None
# 289            NaN         DATE  None  None           NaT              None
# 291            0.0   NOT A DATE  None  None           NaT              None
# 311            6.0         DATE  None  None           NaT              None
# 443            0.0   NOT A DATE  None  None           NaT              None
# 468            4.0         DATE  None  None           NaT              None
# 588            0.0   NOT A DATE  None  None           NaT              None
# 623            5.0         DATE    02  None           NaT              None
# 685            4.0         DATE    06  None           NaT              None
# 700            NaN         DATE  None  None           NaT              None
# 766            4.0         DATE    10  None           NaT              None
# 803            4.0         DATE  None  None           NaT              None
# 809            4.0         DATE    12  None           NaT              None
# 810            0.0   NOT A DATE  None  None           NaT              None
# 909            9.0         DATE  None  None           NaT              None
# 925            NaN         DATE  None  None           NaT              None
# 926            NaN         DATE  None  None           NaT              None
# 944            NaN         DATE  None  None           NaT              None
# 945            0.0   NOT A DATE  None  None           NaT              None
# 946            NaN         DATE  None  None           NaT              None
# 947            0.0   NOT A DATE  None  None           NaT              None
# 948            0.0   NOT A DATE  None  None           NaT              None
# 979            4.0         DATE  None  None           NaT              None
# 997            6.0         DATE  None  None           NaT              None
# 1064           0.0   NOT A DATE  None  None           NaT              None
# 1065           0.0   NOT A DATE  None  None           NaT              None
# 1066           NaN         DATE  None  None           NaT              None
# 1067           0.0   NOT A DATE  None  None           NaT              None
# 1068           0.0   NOT A DATE  None  None           NaT              None
# 1078           NaN         DATE  None  None           NaT              None
# 1211           0.0   NOT A DATE  None  None           NaT              None
# 1212           0.0   NOT A DATE  None  None           NaT              None
# 1213           NaN         DATE  None  None           NaT              None
# 1214           0.0   NOT A DATE  None  None           NaT              None
# 1215           0.0   NOT A DATE  None  None           NaT              None
# 1316           NaN         DATE  None  None           NaT              None
# 1330           5.0         DATE  None  None           NaT              None
# 1365           7.0         DATE  None  None           NaT              None
# 1379           NaN         DATE  None  None           NaT              None
#
#       date_format
# 63          False
# 223         False
# 271         False
# 272         False
# 273         False
# 274         False
# 275         False
# 276         False
# 277         False
# 278         False
# 279         False
# 280         False
# 281         False
# 282         False
# 283         False
# 284         False
# 285         False
# 286         False
# 287         False
# 288         False
# 289         False
# 291         False
# 311         False
# 443         False
# 468         False
# 588         False
# 623         False
# 685         False
# 700         False
# 766         False
# 803         False
# 809         False
# 810         False
# 909         False
# 925         False
# 926         False
# 944         False
# 945         False
# 946         False
# 947         False
# 948         False
# 979         False
# 997         False
# 1064        False
# 1065        False
# 1066        False
# 1067        False
# 1068        False
# 1078        False
# 1211        False
# 1212        False
# 1213        False
# 1214        False
# 1215        False
# 1316        False
# 1330        False
# 1365        False
# 1379        False

# %% [markdown]
# ## Combine to make a function
#
# Now we have gone through how to catch most of the date formats we are going to combine our steps in one function that will take in a date column and spit out cleaned dates with a check date column to make it easy to find dates that need manual verification. So lets collect the bits of code together into one function

# %% [markdown]
# lets collect the functions we need first in the cell below

# %%
from  datetime import datetime
import re 
import pandas as pd
import numpy as np

def count_digits(string):
    try:
        return sum(x.isdigit() for x in string)
    except:
        pass
        
def check_datetime(string):
    if isinstance(string, datetime):
        return 1
    else:
        return 0
    
def extract_month(x, string_list):
    
    input_string = str(x.raw_date).lower()
    date_t = x.raw_datetime_format
    if date_t ==0:
        for substring in string_list:
            if substring in input_string:
                return  str(string_list.index(substring) + 1).zfill(2)
        return None
    else:
        return None
    
def extract_day_2_digits(x):
    input_string = str(x.raw_date)
    date_t = x.raw_datetime_format
    if date_t ==0:
        pattern = r'\b\d{1,2}(?:rd|th|st|nd|yh)\b'
        match = re.search(pattern, input_string)
        if match:
            if len(str(match.group()))==4:
                return str(match.group())[0:2]
            else:
                return str(match.group())[0:1].zfill(2)
        return None
    else:
        return None
    
def extract_day_before_dot(x):
    input_string = str(x.raw_date)
    date_t = x.raw_datetime_format
    day_correct = str(x.day)
    if len(day_correct) != 2:
        if date_t ==0:
            input_string = input_string.strip()
            day = input_string.split('.')[0:3][0]
            if len(day)<3:
                return day.zfill(2)
            else:
                return None
        else:
            return None
            
    else:
        return day_correct
    
def double_slash_datetime(x):
    input_string = str(x.raw_date)
    date_t = x.raw_datetime_format
    day_correct = str(x.day)
    if date_t ==0:
        pattern = r'.*(?<!/)/(?!/).*(?<!/)/(?!/).*'
        if re.match(pattern, input_string):
            try:
                date_time_format = pd.to_datetime(input_string)
                x.day = date_time_format.day
                x.month = date_time_format.month
                return x
            except:
                return x
        else:
            return x
    else: 
        return x
    
def combined_date(x):
    date_t = x.raw_datetime_format
    if date_t == 1:
        return x.raw_date
    else:
        try:
        
            date_string = str(int(x.month)).zfill(2) +'-' + str(int(x.day)).zfill(2) + '-' + str(x.year)
            return pd.to_datetime(date_string)
                                 
        except:
            return None
        
def usa_convert(x):
    try:
        date_obj = x.combined_date
        return  date_obj.strftime('%m/%d/%Y')
    except:
        return None
    
def check_date(x):
    try:
        if len(x.combined_date_USA) == 10:
            return True
        else:
            return False
    except:
        return False

# %% [markdown]
# ### Bring in a sheet with other columns to make the script more usable

# %%
book_name = 'dummy_sheet.xlsx'
write_name = 'dummy_date_cleaned_2.xlsx'
date_column_name = "Date of injury or onset of illness"


xl= pd.read_excel(book_name, sheet_name = None)
sheet_names = xl.keys() 
sheet_names # change this if you want certain sheets excluded
# Out:
# dict_keys(['2021', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012'])

# %% [markdown]
# The cell below combines all of the transformations above and goes across all the sheets

# %%
# def clean_xls_dates(xls_name, xls_new_name):
writer = pd.ExcelWriter(write_name, engine='xlsxwriter')
for sheet_name in list(sheet_names):
    data = pd.read_excel('dummy_sheet.xlsx', sheet_name = sheet_name)
    try:
        result = data.applymap(lambda x: True if date_column_name in str(x) else False)
        rows_to_skip = np.where(result)[0][0]
        data = data.iloc[rows_to_skip:]
        data.rename(columns = data.iloc[0], inplace = True)
        data = data.iloc[1:]
    except:
        pass

    
    months = ["jan", "feb", "mar", "apr", "may", "jun", "jul", "aug", "sep", "oct", "nov", "dec"]
    date_series = data[date_column_name]
    year_series = [sheet_name]*len(date_series)
    df = pd.DataFrame({'raw_date':date_series, 'year': year_series})
    df['raw_datetime_format'] = df.raw_date.apply(lambda x : check_datetime(x))
    df['digit_number'] = df.raw_date.apply(lambda x : count_digits(x))
    df['cleaned_date'] = ['NOT A DATE' if df.digit_number.iloc[i] ==0 else 'DATE' for i in range(len(df))]
    df['month'] = df.apply(lambda x : extract_month(x, months), axis = 1)
    df['day'] = df.apply(lambda x : extract_day_2_digits(x), axis = 1)
    df['day'] = df.apply(lambda x : extract_day_before_dot(x), axis = 1)
    df = df.apply(lambda x : double_slash_datetime(x), axis = 1)
    df['combined_date'] = df.apply(lambda x : combined_date(x), axis = 1)    
    df['combined_date_USA'] = df.apply(lambda x: usa_convert(x), axis =1 )
    df['date_format'] = df.apply(lambda x: check_date(x), axis = 1)
    data['cleaned_date_UK'] = df.combined_date
    data['cleaned_date_USA'] = df.combined_date_USA
    data['date_format_correct'] = df.date_format
    # print(data[data.date_format_correct == False])

    data.to_excel(writer, sheet_name = sheet_name, index = False)
    print(sheet_name)
writer.save()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [53], in <cell line: 2>()
#       1 # def clean_xls_dates(xls_name, xls_new_name):
# ----> 2 writer = pd.ExcelWriter(write_name, engine='xlsxwriter')
#       3 for sheet_name in list(sheet_names):
#       4     data = pd.read_excel('dummy_sheet.xlsx', sheet_name = sheet_name)
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py:191, in XlsxWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     188 if mode == "a":
#     189     raise ValueError("Append mode is not supported with xlsxwriter!")
# --> 191 super().__init__(
#     192     path,
#     193     engine=engine,
#     194     date_format=date_format,
#     195     datetime_format=datetime_format,
#     196     mode=mode,
#     197     storage_options=storage_options,
#     198     if_sheet_exists=if_sheet_exists,
#     199     engine_kwargs=engine_kwargs,
#     200 )
#     202 self.book = Workbook(self.handles.handle, **engine_kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1106, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1102 self.handles = IOHandles(
#    1103     cast(IO[bytes], path), compression={"compression": None}
#    1104 )
#    1105 if not isinstance(path, ExcelWriter):
# -> 1106     self.handles = get_handle(
#    1107         path, mode, storage_options=storage_options, is_text=False
#    1108     )
#    1109 self.sheets: dict[str, Any] = {}
#    1110 self.cur_sheet = None
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:798, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#    (...)
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
# --> 798         handle = open(handle, ioargs.mode)
#     799     handles.append(handle)
#     801 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: 'dummy_date_cleaned_2.xlsx'

# %% [markdown]
# At this point you should open up your new sheet in excel and manauly change the remaining ones using the date format correct column as a flag

# %%
writer.close()
# Out:
# C:\Users\PeterBaksh\anaconda3\lib\site-packages\xlsxwriter\workbook.py:339: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")
